# %%
pip install mecab-python3
# Out:
# Collecting mecab-python3
#   Downloading mecab-python3-1.0.4.tar.gz (78 kB)
#      |████████████████████████████████| 78 kB 2.9 MB/s
#   Preparing metadata (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /home/sangi2/anaconda3/envs/mecab/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-z0goc1ar/mecab-python3_5ca166e0ca254ca595ab5ef3b8843ebe/setup.py'"'"'; __file__='"'"'/tmp/pip-install-z0goc1ar/mecab-python3_5ca166e0ca254ca595ab5ef3b8843ebe/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-6iq6aa3o
#        cwd: /tmp/pip-install-z0goc1ar/mecab-python3_5ca166e0ca254ca595ab5ef3b8843ebe/
#   Complete output (41 lines):
#   /home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/installer.py:27: SetuptoolsDeprecationWarning: setuptools.installer is deprecated. Requirements should be satisfied by a PEP 517 installer.
#     warnings.warn(
#   running egg_info
#   creating /tmp/pip-pip-egg-info-6iq6aa3o/mecab_python3.egg-info
#   writing /tmp/pip-pip-egg-info-6iq6aa3o/mecab_python3.egg-info/PKG-INFO
#   writing dependency_links to /tmp/pip-pip-egg-info-6iq6aa3o/mecab_python3.egg-info/dependency_links.txt
#   writing entry points to /tmp/pip-pip-egg-info-6iq6aa3o/mecab_python3.egg-info/entry_points.txt
#   writing requirements to /tmp/pip-pip-egg-info-6iq6aa3o/mecab_python3.egg-info/requires.txt
#   writing top-level names to /tmp/pip-pip-egg-info-6iq6aa3o/mecab_python3.egg-info/top_level.txt
#   writing manifest file '/tmp/pip-pip-egg-info-6iq6aa3o/mecab_python3.egg-info/SOURCES.txt'
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "/tmp/pip-install-z0goc1ar/mecab-python3_5ca166e0ca254ca595ab5ef3b8843ebe/setup.py", line 201, in <module>
#       setup(name = "mecab-python3",
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/__init__.py", line 153, in setup
#       return distutils.core.setup(**attrs)
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/distutils/core.py", line 148, in setup
#       dist.run_commands()
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/distutils/dist.py", line 966, in run_commands
#       self.run_command(cmd)
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/distutils/dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/egg_info.py", line 299, in run
#       self.find_sources()
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/egg_info.py", line 306, in find_sources
#       mm.run()
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/egg_info.py", line 541, in run
#       self.add_defaults()
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/egg_info.py", line 578, in add_defaults
#       sdist.add_defaults(self)
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/distutils/command/sdist.py", line 226, in add_defaults
#       self._add_defaults_python()
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/sdist.py", line 113, in _add_defaults_python
#       self._add_data_files(self._safe_data_files(build_py))
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/sdist.py", line 132, in _add_data_files
#       self.filelist.extend(
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/egg_info.py", line 489, in extend
#       self.files.extend(filter(self._safe_path, paths))
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/sdist.py", line 134, in <genexpr>
#       for _, src_dir, _, filenames in data_files
#   ValueError: not enough values to unpack (expected 4, got 1)
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/5a/90/348cda0312df7ff25d57ca56560b6871be42e48a99b1ddc091f6f23e96cc/mecab-python3-1.0.4.tar.gz#sha256=b150ad5fe4260539b4ef184657e552ef81307fbbe60ae1f258bc814549ea90f8 (from https://pypi.org/simple/mecab-python3/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading mecab-python3-1.0.3.tar.gz (77 kB)
#      |████████████████████████████████| 77 kB 5.0 MB/s
#   Preparing metadata (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /home/sangi2/anaconda3/envs/mecab/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-z0goc1ar/mecab-python3_f713725c37ce47439e96bf8b0553b1c7/setup.py'"'"'; __file__='"'"'/tmp/pip-install-z0goc1ar/mecab-python3_f713725c37ce47439e96bf8b0553b1c7/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-xhw7q6_2
#        cwd: /tmp/pip-install-z0goc1ar/mecab-python3_f713725c37ce47439e96bf8b0553b1c7/
#   Complete output (41 lines):
#   /home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/installer.py:27: SetuptoolsDeprecationWarning: setuptools.installer is deprecated. Requirements should be satisfied by a PEP 517 installer.
#     warnings.warn(
#   running egg_info
#   creating /tmp/pip-pip-egg-info-xhw7q6_2/mecab_python3.egg-info
#   writing /tmp/pip-pip-egg-info-xhw7q6_2/mecab_python3.egg-info/PKG-INFO
#   writing dependency_links to /tmp/pip-pip-egg-info-xhw7q6_2/mecab_python3.egg-info/dependency_links.txt
#   writing entry points to /tmp/pip-pip-egg-info-xhw7q6_2/mecab_python3.egg-info/entry_points.txt
#   writing requirements to /tmp/pip-pip-egg-info-xhw7q6_2/mecab_python3.egg-info/requires.txt
#   writing top-level names to /tmp/pip-pip-egg-info-xhw7q6_2/mecab_python3.egg-info/top_level.txt
#   writing manifest file '/tmp/pip-pip-egg-info-xhw7q6_2/mecab_python3.egg-info/SOURCES.txt'
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "/tmp/pip-install-z0goc1ar/mecab-python3_f713725c37ce47439e96bf8b0553b1c7/setup.py", line 201, in <module>
#       setup(name = "mecab-python3",
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/__init__.py", line 153, in setup
#       return distutils.core.setup(**attrs)
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/distutils/core.py", line 148, in setup
#       dist.run_commands()
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/distutils/dist.py", line 966, in run_commands
#       self.run_command(cmd)
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/distutils/dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/egg_info.py", line 299, in run
#       self.find_sources()
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/egg_info.py", line 306, in find_sources
#       mm.run()
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/egg_info.py", line 541, in run
#       self.add_defaults()
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/egg_info.py", line 578, in add_defaults
#       sdist.add_defaults(self)
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/distutils/command/sdist.py", line 226, in add_defaults
#       self._add_defaults_python()
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/sdist.py", line 113, in _add_defaults_python
#       self._add_data_files(self._safe_data_files(build_py))
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/sdist.py", line 132, in _add_data_files
#       self.filelist.extend(
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/egg_info.py", line 489, in extend
#       self.files.extend(filter(self._safe_path, paths))
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/sdist.py", line 134, in <genexpr>
#       for _, src_dir, _, filenames in data_files
#   ValueError: not enough values to unpack (expected 4, got 1)
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/6c/71/fc591b2411a4f04c674beafd67c5d7b22873a50f4e5ebe9cfe3dc3d46e3c/mecab-python3-1.0.3.tar.gz#sha256=62abe28a1155398325372291483608427bc82681fef80e7d132904415f9fd42e (from https://pypi.org/simple/mecab-python3/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading mecab-python3-1.0.2.tar.gz (108 kB)
#      |████████████████████████████████| 108 kB 11.6 MB/s
#   Preparing metadata (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /home/sangi2/anaconda3/envs/mecab/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-z0goc1ar/mecab-python3_9dc6a5c0d0f947c4a581de7ea83e08ef/setup.py'"'"'; __file__='"'"'/tmp/pip-install-z0goc1ar/mecab-python3_9dc6a5c0d0f947c4a581de7ea83e08ef/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-vwp4gcmo
#        cwd: /tmp/pip-install-z0goc1ar/mecab-python3_9dc6a5c0d0f947c4a581de7ea83e08ef/
#   Complete output (41 lines):
#   /home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/installer.py:27: SetuptoolsDeprecationWarning: setuptools.installer is deprecated. Requirements should be satisfied by a PEP 517 installer.
#     warnings.warn(
#   running egg_info
#   creating /tmp/pip-pip-egg-info-vwp4gcmo/mecab_python3.egg-info
#   writing /tmp/pip-pip-egg-info-vwp4gcmo/mecab_python3.egg-info/PKG-INFO
#   writing dependency_links to /tmp/pip-pip-egg-info-vwp4gcmo/mecab_python3.egg-info/dependency_links.txt
#   writing entry points to /tmp/pip-pip-egg-info-vwp4gcmo/mecab_python3.egg-info/entry_points.txt
#   writing requirements to /tmp/pip-pip-egg-info-vwp4gcmo/mecab_python3.egg-info/requires.txt
#   writing top-level names to /tmp/pip-pip-egg-info-vwp4gcmo/mecab_python3.egg-info/top_level.txt
#   writing manifest file '/tmp/pip-pip-egg-info-vwp4gcmo/mecab_python3.egg-info/SOURCES.txt'
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "/tmp/pip-install-z0goc1ar/mecab-python3_9dc6a5c0d0f947c4a581de7ea83e08ef/setup.py", line 201, in <module>
#       setup(name = "mecab-python3",
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/__init__.py", line 153, in setup
#       return distutils.core.setup(**attrs)
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/distutils/core.py", line 148, in setup
#       dist.run_commands()
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/distutils/dist.py", line 966, in run_commands
#       self.run_command(cmd)
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/distutils/dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/egg_info.py", line 299, in run
#       self.find_sources()
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/egg_info.py", line 306, in find_sources
#       mm.run()
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/egg_info.py", line 541, in run
#       self.add_defaults()
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/egg_info.py", line 578, in add_defaults
#       sdist.add_defaults(self)
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/distutils/command/sdist.py", line 226, in add_defaults
#       self._add_defaults_python()
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/sdist.py", line 113, in _add_defaults_python
#       self._add_data_files(self._safe_data_files(build_py))
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/sdist.py", line 132, in _add_data_files
#       self.filelist.extend(
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/egg_info.py", line 489, in extend
#       self.files.extend(filter(self._safe_path, paths))
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/sdist.py", line 134, in <genexpr>
#       for _, src_dir, _, filenames in data_files
#   ValueError: not enough values to unpack (expected 4, got 1)
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/f0/9f/e03c50f58c94934c9ec87c26a3e9a147c8beecb5e716dca78e3de0ffb57a/mecab-python3-1.0.2.tar.gz#sha256=eefdff160ba231acb21afab5c775bc2e024b3164c637a23b599b270d45feb32d (from https://pypi.org/simple/mecab-python3/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading mecab-python3-1.0.1.tar.gz (108 kB)
#      |████████████████████████████████| 108 kB 18.1 MB/s
#   Preparing metadata (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /home/sangi2/anaconda3/envs/mecab/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-z0goc1ar/mecab-python3_91bfaf98ee144ef0acceb658dd7730d3/setup.py'"'"'; __file__='"'"'/tmp/pip-install-z0goc1ar/mecab-python3_91bfaf98ee144ef0acceb658dd7730d3/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-9vibiq42
#        cwd: /tmp/pip-install-z0goc1ar/mecab-python3_91bfaf98ee144ef0acceb658dd7730d3/
#   Complete output (40 lines):
#   /home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/installer.py:27: SetuptoolsDeprecationWarning: setuptools.installer is deprecated. Requirements should be satisfied by a PEP 517 installer.
#     warnings.warn(
#   running egg_info
#   creating /tmp/pip-pip-egg-info-9vibiq42/mecab_python3.egg-info
#   writing /tmp/pip-pip-egg-info-9vibiq42/mecab_python3.egg-info/PKG-INFO
#   writing dependency_links to /tmp/pip-pip-egg-info-9vibiq42/mecab_python3.egg-info/dependency_links.txt
#   writing requirements to /tmp/pip-pip-egg-info-9vibiq42/mecab_python3.egg-info/requires.txt
#   writing top-level names to /tmp/pip-pip-egg-info-9vibiq42/mecab_python3.egg-info/top_level.txt
#   writing manifest file '/tmp/pip-pip-egg-info-9vibiq42/mecab_python3.egg-info/SOURCES.txt'
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "/tmp/pip-install-z0goc1ar/mecab-python3_91bfaf98ee144ef0acceb658dd7730d3/setup.py", line 201, in <module>
#       setup(name = "mecab-python3",
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/__init__.py", line 153, in setup
#       return distutils.core.setup(**attrs)
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/distutils/core.py", line 148, in setup
#       dist.run_commands()
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/distutils/dist.py", line 966, in run_commands
#       self.run_command(cmd)
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/distutils/dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/egg_info.py", line 299, in run
#       self.find_sources()
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/egg_info.py", line 306, in find_sources
#       mm.run()
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/egg_info.py", line 541, in run
#       self.add_defaults()
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/egg_info.py", line 578, in add_defaults
#       sdist.add_defaults(self)
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/distutils/command/sdist.py", line 226, in add_defaults
#       self._add_defaults_python()
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/sdist.py", line 113, in _add_defaults_python
#       self._add_data_files(self._safe_data_files(build_py))
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/sdist.py", line 132, in _add_data_files
#       self.filelist.extend(
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/egg_info.py", line 489, in extend
#       self.files.extend(filter(self._safe_path, paths))
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/sdist.py", line 134, in <genexpr>
#       for _, src_dir, _, filenames in data_files
#   ValueError: not enough values to unpack (expected 4, got 1)
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/df/ea/9dfb636a4887a35c95f85e82382dbe5c44c55dc5b3daf90bb703405bc7ab/mecab-python3-1.0.1.tar.gz#sha256=d56d27e4d30be72cff7a2436dbc9de99b8cb590954a26dcbd1326c345de78608 (from https://pypi.org/simple/mecab-python3/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading mecab-python3-1.0.0.tar.gz (108 kB)
#      |████████████████████████████████| 108 kB 23.6 MB/s
#   Preparing metadata (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /home/sangi2/anaconda3/envs/mecab/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-z0goc1ar/mecab-python3_6912efbebad5463e984bf37e2d4ec3bc/setup.py'"'"'; __file__='"'"'/tmp/pip-install-z0goc1ar/mecab-python3_6912efbebad5463e984bf37e2d4ec3bc/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-dmi5eymz
#        cwd: /tmp/pip-install-z0goc1ar/mecab-python3_6912efbebad5463e984bf37e2d4ec3bc/
#   Complete output (40 lines):
#   /home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/installer.py:27: SetuptoolsDeprecationWarning: setuptools.installer is deprecated. Requirements should be satisfied by a PEP 517 installer.
#     warnings.warn(
#   running egg_info
#   creating /tmp/pip-pip-egg-info-dmi5eymz/mecab_python3.egg-info
#   writing /tmp/pip-pip-egg-info-dmi5eymz/mecab_python3.egg-info/PKG-INFO
#   writing dependency_links to /tmp/pip-pip-egg-info-dmi5eymz/mecab_python3.egg-info/dependency_links.txt
#   writing requirements to /tmp/pip-pip-egg-info-dmi5eymz/mecab_python3.egg-info/requires.txt
#   writing top-level names to /tmp/pip-pip-egg-info-dmi5eymz/mecab_python3.egg-info/top_level.txt
#   writing manifest file '/tmp/pip-pip-egg-info-dmi5eymz/mecab_python3.egg-info/SOURCES.txt'
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "/tmp/pip-install-z0goc1ar/mecab-python3_6912efbebad5463e984bf37e2d4ec3bc/setup.py", line 201, in <module>
#       setup(name = "mecab-python3",
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/__init__.py", line 153, in setup
#       return distutils.core.setup(**attrs)
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/distutils/core.py", line 148, in setup
#       dist.run_commands()
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/distutils/dist.py", line 966, in run_commands
#       self.run_command(cmd)
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/distutils/dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/egg_info.py", line 299, in run
#       self.find_sources()
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/egg_info.py", line 306, in find_sources
#       mm.run()
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/egg_info.py", line 541, in run
#       self.add_defaults()
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/egg_info.py", line 578, in add_defaults
#       sdist.add_defaults(self)
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/distutils/command/sdist.py", line 226, in add_defaults
#       self._add_defaults_python()
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/sdist.py", line 113, in _add_defaults_python
#       self._add_data_files(self._safe_data_files(build_py))
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/sdist.py", line 132, in _add_data_files
#       self.filelist.extend(
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/egg_info.py", line 489, in extend
#       self.files.extend(filter(self._safe_path, paths))
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/sdist.py", line 134, in <genexpr>
#       for _, src_dir, _, filenames in data_files
#   ValueError: not enough values to unpack (expected 4, got 1)
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/ea/10/230b6056c6ed3bbba0e3a705ef11f813936d41aa96d494ecebc66ab34fc5/mecab-python3-1.0.0.tar.gz#sha256=5c92be050b32e4cdc1811955e5ea60ae0fc6c7176d4d5e82c5d09530c317a476 (from https://pypi.org/simple/mecab-python3/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading mecab-python3-0.996.5.tar.gz (65 kB)
#      |████████████████████████████████| 65 kB 5.3 MB/s
#   Preparing metadata (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /home/sangi2/anaconda3/envs/mecab/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-z0goc1ar/mecab-python3_de4975584d464bb08a5f561fb8526945/setup.py'"'"'; __file__='"'"'/tmp/pip-install-z0goc1ar/mecab-python3_de4975584d464bb08a5f561fb8526945/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-h52mjqi5
#        cwd: /tmp/pip-install-z0goc1ar/mecab-python3_de4975584d464bb08a5f561fb8526945/
#   Complete output (39 lines):
#   /home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/installer.py:27: SetuptoolsDeprecationWarning: setuptools.installer is deprecated. Requirements should be satisfied by a PEP 517 installer.
#     warnings.warn(
#   running egg_info
#   creating /tmp/pip-pip-egg-info-h52mjqi5/mecab_python3.egg-info
#   writing /tmp/pip-pip-egg-info-h52mjqi5/mecab_python3.egg-info/PKG-INFO
#   writing dependency_links to /tmp/pip-pip-egg-info-h52mjqi5/mecab_python3.egg-info/dependency_links.txt
#   writing top-level names to /tmp/pip-pip-egg-info-h52mjqi5/mecab_python3.egg-info/top_level.txt
#   writing manifest file '/tmp/pip-pip-egg-info-h52mjqi5/mecab_python3.egg-info/SOURCES.txt'
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "/tmp/pip-install-z0goc1ar/mecab-python3_de4975584d464bb08a5f561fb8526945/setup.py", line 237, in <module>
#       setup(name = "mecab-python3",
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/__init__.py", line 153, in setup
#       return distutils.core.setup(**attrs)
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/distutils/core.py", line 148, in setup
#       dist.run_commands()
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/distutils/dist.py", line 966, in run_commands
#       self.run_command(cmd)
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/distutils/dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/egg_info.py", line 299, in run
#       self.find_sources()
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/egg_info.py", line 306, in find_sources
#       mm.run()
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/egg_info.py", line 541, in run
#       self.add_defaults()
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/egg_info.py", line 578, in add_defaults
#       sdist.add_defaults(self)
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/distutils/command/sdist.py", line 226, in add_defaults
#       self._add_defaults_python()
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/sdist.py", line 113, in _add_defaults_python
#       self._add_data_files(self._safe_data_files(build_py))
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/sdist.py", line 132, in _add_data_files
#       self.filelist.extend(
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/egg_info.py", line 489, in extend
#       self.files.extend(filter(self._safe_path, paths))
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/sdist.py", line 134, in <genexpr>
#       for _, src_dir, _, filenames in data_files
#   ValueError: not enough values to unpack (expected 4, got 1)
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/55/84/37349dc897456c25600b498f88c8988a7d6754ebe96c189897c54bd24684/mecab-python3-0.996.5.tar.gz#sha256=e7f09caf136903ce908b8b001ffc178d6caa129c1550d47d8f7f733a213749a8 (from https://pypi.org/simple/mecab-python3/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading mecab-python3-0.996.3.tar.gz (63 kB)
#      |████████████████████████████████| 63 kB 1.2 MB/s
#   Preparing metadata (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /home/sangi2/anaconda3/envs/mecab/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-z0goc1ar/mecab-python3_c647e22d8289416db1192afe6d56a1ab/setup.py'"'"'; __file__='"'"'/tmp/pip-install-z0goc1ar/mecab-python3_c647e22d8289416db1192afe6d56a1ab/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-qicdxhy6
#        cwd: /tmp/pip-install-z0goc1ar/mecab-python3_c647e22d8289416db1192afe6d56a1ab/
#   Complete output (39 lines):
#   /home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/installer.py:27: SetuptoolsDeprecationWarning: setuptools.installer is deprecated. Requirements should be satisfied by a PEP 517 installer.
#     warnings.warn(
#   running egg_info
#   creating /tmp/pip-pip-egg-info-qicdxhy6/mecab_python3.egg-info
#   writing /tmp/pip-pip-egg-info-qicdxhy6/mecab_python3.egg-info/PKG-INFO
#   writing dependency_links to /tmp/pip-pip-egg-info-qicdxhy6/mecab_python3.egg-info/dependency_links.txt
#   writing top-level names to /tmp/pip-pip-egg-info-qicdxhy6/mecab_python3.egg-info/top_level.txt
#   writing manifest file '/tmp/pip-pip-egg-info-qicdxhy6/mecab_python3.egg-info/SOURCES.txt'
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "/tmp/pip-install-z0goc1ar/mecab-python3_c647e22d8289416db1192afe6d56a1ab/setup.py", line 237, in <module>
#       setup(name = "mecab-python3",
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/__init__.py", line 153, in setup
#       return distutils.core.setup(**attrs)
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/distutils/core.py", line 148, in setup
#       dist.run_commands()
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/distutils/dist.py", line 966, in run_commands
#       self.run_command(cmd)
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/distutils/dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/egg_info.py", line 299, in run
#       self.find_sources()
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/egg_info.py", line 306, in find_sources
#       mm.run()
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/egg_info.py", line 541, in run
#       self.add_defaults()
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/egg_info.py", line 578, in add_defaults
#       sdist.add_defaults(self)
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/distutils/command/sdist.py", line 226, in add_defaults
#       self._add_defaults_python()
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/sdist.py", line 113, in _add_defaults_python
#       self._add_data_files(self._safe_data_files(build_py))
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/sdist.py", line 132, in _add_data_files
#       self.filelist.extend(
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/egg_info.py", line 489, in extend
#       self.files.extend(filter(self._safe_path, paths))
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/sdist.py", line 134, in <genexpr>
#       for _, src_dir, _, filenames in data_files
#   ValueError: not enough values to unpack (expected 4, got 1)
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/3a/9a/86449a66d689d54ea623b86ad0fa4f950b79d7b2a8395d59dfe2da87f78b/mecab-python3-0.996.3.tar.gz#sha256=1cedc968ef5bcbb2a6ece3bb4eb26e9569d89f3277dc2066ea0ce1341ab7d3b9 (from https://pypi.org/simple/mecab-python3/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading mecab-python3-0.996.2.tar.gz (61 kB)
#      |████████████████████████████████| 61 kB 280 kB/s
#   Preparing metadata (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /home/sangi2/anaconda3/envs/mecab/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-z0goc1ar/mecab-python3_b86894b187284e41b47dc6c4307e04b3/setup.py'"'"'; __file__='"'"'/tmp/pip-install-z0goc1ar/mecab-python3_b86894b187284e41b47dc6c4307e04b3/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-__v_nx1q
#        cwd: /tmp/pip-install-z0goc1ar/mecab-python3_b86894b187284e41b47dc6c4307e04b3/
#   Complete output (39 lines):
#   /home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/installer.py:27: SetuptoolsDeprecationWarning: setuptools.installer is deprecated. Requirements should be satisfied by a PEP 517 installer.
#     warnings.warn(
#   running egg_info
#   creating /tmp/pip-pip-egg-info-__v_nx1q/mecab_python3.egg-info
#   writing /tmp/pip-pip-egg-info-__v_nx1q/mecab_python3.egg-info/PKG-INFO
#   writing dependency_links to /tmp/pip-pip-egg-info-__v_nx1q/mecab_python3.egg-info/dependency_links.txt
#   writing top-level names to /tmp/pip-pip-egg-info-__v_nx1q/mecab_python3.egg-info/top_level.txt
#   writing manifest file '/tmp/pip-pip-egg-info-__v_nx1q/mecab_python3.egg-info/SOURCES.txt'
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "/tmp/pip-install-z0goc1ar/mecab-python3_b86894b187284e41b47dc6c4307e04b3/setup.py", line 237, in <module>
#       setup(name = "mecab-python3",
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/__init__.py", line 153, in setup
#       return distutils.core.setup(**attrs)
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/distutils/core.py", line 148, in setup
#       dist.run_commands()
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/distutils/dist.py", line 966, in run_commands
#       self.run_command(cmd)
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/distutils/dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/egg_info.py", line 299, in run
#       self.find_sources()
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/egg_info.py", line 306, in find_sources
#       mm.run()
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/egg_info.py", line 541, in run
#       self.add_defaults()
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/egg_info.py", line 578, in add_defaults
#       sdist.add_defaults(self)
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/distutils/command/sdist.py", line 226, in add_defaults
#       self._add_defaults_python()
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/sdist.py", line 113, in _add_defaults_python
#       self._add_data_files(self._safe_data_files(build_py))
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/sdist.py", line 132, in _add_data_files
#       self.filelist.extend(
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/egg_info.py", line 489, in extend
#       self.files.extend(filter(self._safe_path, paths))
#     File "/home/sangi2/anaconda3/envs/mecab/lib/python3.10/site-packages/setuptools/command/sdist.py", line 134, in <genexpr>
#       for _, src_dir, _, filenames in data_files
#   ValueError: not enough values to unpack (expected 4, got 1)
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/6b/9d/38d24176cb9f38c5c48c3ed837e3102a738fe197b05c31e6d2ba534dcd86/mecab-python3-0.996.2.tar.gz#sha256=a80383fba343dad247b486a9afa486b7f0ec6244cb8bbf2d6a24d2fab5f19180 (from https://pypi.org/simple/mecab-python3/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading mecab-python3-0.996.1.tar.gz (27 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: mecab-python3
#   Building wheel for mecab-python3 (setup.py) ... done
#   Created wheel for mecab-python3: filename=mecab_python3-0.996.1-cp310-cp310-linux_x86_64.whl size=141550 sha256=ef6dbb01036d721fa97c88477624a82f52014b90504ceb3c2cf489be54ac9f53
#   Stored in directory: /home/sangi2/.cache/pip/wheels/ca/ca/c1/b17304063e7f67965eaf29abf2959746363a571d3c5b73a9bb
# Successfully built mecab-python3
# Installing collected packages: mecab-python3
# Successfully installed mecab-python3-0.996.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import MeCab

m = MeCab.Tagger ("-Ochasen")
print(m.parse ("すもももももももものうち"))
# Out:
# すもも	スモモ	すもも	名詞-一般
# も	モ	も	助詞-係助詞
# もも	モモ	もも	名詞-一般
# も	モ	も	助詞-係助詞
# もも	モモ	もも	名詞-一般
# の	ノ	の	助詞-連体化
# うち	ウチ	うち	名詞-非自立-副詞可能
# EOS

# %%
m = MeCab.Tagger ("-Owakati")
print(m.parse ("すもももももももものうち"))
# Out:
# すもも も もも も もも の うち

# %%
m = MeCab.Tagger ()
print(m.parse ("スマートグラス"))
# Out:
# スマート	名詞,固有名詞,人名,姓,*,*,スマート,スマート,スマート
# グラス	名詞,一般,*,*,*,*,グラス,グラス,グラス
# EOS

# %%
m = MeCab.Tagger ("-d /usr/local/lib/mecab/dic/mecab-ipadic-neologd")
print(m.parse ("スマートグラス"))
# Out:
# スマートグラス	名詞,固有名詞,一般,*,*,*,Smart Glass,スマートグラス,スマートグラス
# EOS

# %%
m = MeCab.Tagger ("-d /usr/local/lib/mecab/dic/mecab-ipadic-neologd")
print(m.parse ("Googleグラス"))
# Out:
# Google	名詞,固有名詞,一般,*,*,*,Google,グーグル,グーグル
# グラス	名詞,一般,*,*,*,*,グラス,グラス,グラス
# EOS

# %%
tagger = MeCab.Tagger("-d /usr/local/lib/mecab/dic/mecab-ipadic-neologd")
#tagger = MeCab.Tagger()
print(tagger.parse('フシギダネは不思議だね。'))
# Out:
# フシギダネ	名詞,固有名詞,人名,一般,*,*,フシギダネ,フシギダネ,フシギダネ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 不思議	名詞,形容動詞語幹,*,*,*,*,不思議,フシギ,フシギ
# だ	助動詞,*,*,*,特殊・ダ,基本形,だ,ダ,ダ
# ね	助詞,終助詞,*,*,*,*,ね,ネ,ネ
# 。	記号,句点,*,*,*,*,。,。,。
# EOS
